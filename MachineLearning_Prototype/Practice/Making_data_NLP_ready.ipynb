# %%
# importinng dependencies
import pandas as pd

# %%
# import Sample Table 1
sample_review_df = pd.read_csv("tables/sample_table_hotel_reviews.csv")
sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %% [markdown]
# # Merging positive and negative review columns into 1 column

# %%
# changing the No Negative to null
sample_review_df.loc[(sample_review_df["Negative_Review"] == "No Negative"), "Negative_Review"] = ''

# changing the No Positive to null
sample_review_df.loc[(sample_review_df["Positive_Review"] == "No Positive"), "Positive_Review"] = ''

sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %%
# merge positve and negative review columns into a 'Combined review' column
sample_review_df["Combined_Review"] = sample_review_df["Negative_Review"] + sample_review_df["Positive_Review"]

sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %%
# export as csv
sample_review_df.to_csv('sample_table_for_NLP.csv', index=False)
