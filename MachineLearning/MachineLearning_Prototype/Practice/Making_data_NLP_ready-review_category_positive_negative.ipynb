# %%
# importinng dependencies
import pandas as pd

# %%
# import Sample Table 1
sample_review_df = pd.read_csv("sample_table_for_NLP.csv")
sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %%
sample_review_df["Review_Class"] = ""

sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %%
sample_review_df.dtypes
# Out:
# Id                                              int64
# Hotel_Address                                  object
# Additional_Number_of_Scoring                    int64
# Review_Date                                    object
# Average_Score                                 float64
# Hotel_Name                                     object
# Reviewer_Nationality                           object
# Negative_Review                                object
# Review_Total_Negative_Word_Counts               int64
# Total_Number_of_Reviews                         int64
# Positive_Review                                object
# Review_Total_Positive_Word_Counts               int64
# Total_Number_of_Reviews_Reviewer_Has_Given      int64
# Reviewer_Score                                float64
# Tags                                           object
# days_since_review                              object
# Combined_Review                                object
# ...

# %%
# For Scores <= 4.9, changing the value in 'review'

sample_review_df.loc[sample_review_df["Reviewer_Score"] <= 4.9, "Review_Class"] = "negative"
sample_review_df.loc[sample_review_df["Reviewer_Score"] >= 5.0, "Review_Class"] = "positive"

sample_review_df
# Out:
#       Id                                      Hotel_Address  \
# 0      0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1      1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2      2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3      3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4      4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ..   ...                                                ...
# 995  995  1 2 Serjeant s Inn Fleet Street City of London...
# 996  996  1 2 Serjeant s Inn Fleet Street City of London...
# 997  997  1 2 Serjeant s Inn Fleet Street City of London...
# 998  998  1 2 Serjeant s Inn Fleet Street City of London...
# 999  999  1 2 Serjeant s Inn Fleet Street City of London...
#
#      Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                             194    8/3/2017            7.7
# 1                             194    8/3/2017            7.7
# ...

# %%
# Exporting the categorical_reviews
sample_review_df.to_csv('Sample_positive_negative_review_table.csv', index=False)
